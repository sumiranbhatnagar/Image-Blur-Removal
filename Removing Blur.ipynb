# %%
import cv2
import numpy as np
from PIL import Image, ImageEnhance
import matplotlib.pyplot
image = cv2.imread('input.jpeg')
cv2.imshow('sharpenimages ', image)
kernel = np.ones((5,5),np.float32)/25
dst = cv2.filter2D(image,-1,kernel)
#cv2.imshow('dst' , dst)
sharpen_kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
sharpen = cv2.filter2D(dst, -1, sharpen_kernel)
#cv2.imshow('sharpen', sharpen)
dst1 = cv2.filter2D(sharpen,-1,kernel)
#cv2.imshow('dst1' , dst1)
sharpen1 = cv2.filter2D(dst1, -1, sharpen_kernel)
#cv2.imshow('sharpen1', sharpen1)
dst2 = cv2.filter2D(sharpen1,-1,kernel)
#cv2.imshow('dst2' , dst2)
sharpen2 = cv2.filter2D(dst2, -1, sharpen_kernel)
#cv2.imshow('sharpen2', sharpen2)


blur2 = cv2.GaussianBlur(sharpen2,(5,5),0)
cv2.imshow('blura', blur2)




sharpen3 = cv2.filter2D(blur2, -1, sharpen_kernel)
#cv2.imshow('sharpen3', sharpen3)  

sharpen4 = cv2.filter2D(sharpen3, -1, sharpen_kernel)
#cv2.imshow('sharpen4', sharpen4)
blur2 = cv2.GaussianBlur(sharpen2,(5,5),0)
#cv2.imshow('blura', blur2)
import cv2
import numpy as np
image = cv2.imread('input.jpeg')
cv2.imshow('sharpenimages ', image)
kernel = np.ones((5,5),np.float32)/25
dst = cv2.filter2D(image,-1,kernel)
cv2.imshow('dst' , dst)
sharpen_kernel = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
sharpen = cv2.filter2D(dst, -1, sharpen_kernel)
cv2.imshow('sharpen', sharpen)
dst1 = cv2.filter2D(sharpen,-1,kernel)
cv2.imshow('dst1' , dst1)
sharpen1 = cv2.filter2D(dst1, -1, sharpen_kernel)
cv2.imshow('sharpen1', sharpen1)
dst2 = cv2.filter2D(sharpen1,-1,kernel)
cv2.imshow('dst2' , dst2)
sharpen2 = cv2.filter2D(dst2, -1, sharpen_kernel)
cv2.imshow('sharpen2', sharpen2)


blur2 = cv2.GaussianBlur(sharpen2,(5,5),0)
cv2.imshow('blura', blur2)



#blur3 = cv2.GaussianBlur(blur2,(5,5),0)
#cv2.imshow('blurb', blur3)
#blur = cv2.bilateralFilter(blur2,9,75,75)
#cv2.imshow('blur', blur)
#blur3 = cv2.GaussianBlur(blur,(5,5),0)
#cv2.imshow('blurb', blur3)

sharpen3 = cv2.filter2D(blur2, -1, sharpen_kernel)
cv2.imshow('sharpen3', sharpen3)

sharpen4 = cv2.filter2D(sharpen3, -1, sharpen_kernel)
cv2.imshow('sharpen4', sharpen4)
blur3 = cv2.GaussianBlur(sharpen4,(5,5),0)
cv2.imshow('blurc', blur3)
lur = cv2.bilateralFilter(blur3, 9,75,75)
cv2.imshow("lurs", lur)
lur1 = cv2.bilateralFilter(lur, 9,75,75)
cv2.imshow("lurs", lur1)
blur5 = cv2.GaussianBlur(lur1, (5,5),0)
cv2.imshow('blur5', blur5)
sharpen6 = cv2.filter2D(blur5, -1, sharpen_kernel)
cv2.imshow('sharpen6', sharpen6)
lur2 = cv2.bilateralFilter(sharpen6 , 9,75,75)
cv2.imshow("lur2", lur2)
blur6 = cv2.GaussianBlur(lur2, (5,5),0)
cv2.imshow('blur6', blur6)
blur7 = cv2.GaussianBlur(blur6, (5,5),0)
cv2.imshow('blur7', blur7)
blur8 = cv2.GaussianBlur(blur7, (5,5),0)
cv2.imshow('blur8', blur8)
blur9 = cv2.GaussianBlur(blur8, (5,5),0)
cv2.imshow('blur9', blur9)
lur3 = cv2.bilateralFilter(blur9, 9,75,75)
cv2.imshow("lur3", lur3)
sharpenk = cv2.filter2D(lur3, -1, sharpen_kernel)
sharpen7 = cv2.filter2D(sharpenk, -1, sharpen_kernel)
cv2.imshow('sharpen7', sharpen7)
blur8 = cv2.GaussianBlur(sharpen7, (5,5),0)
cv2.imshow('blur8', blur8)
blur9 = cv2.GaussianBlur(blur8, (5,5),0)
cv2.imshow('blur9', blur9)
lur4 = cv2.bilateralFilter(blur9, 9,75,75)
cv2.imshow("lur4", lur4)
blur10 = cv2.GaussianBlur(lur4, (5,5),0)
cv2.imshow('blur10', blur10)
median = cv2.medianBlur(blur10,5)
cv2.imshow('median', median)
cv2.imwrite('Final_Output.jpeg', lur3)
cv2.imwrite('Final_Output2.jpeg', median)

cv2.waitKey()

# %% [markdown]
# ##### Trash Code

# %% [raw]
# import cv2
# import numpy as np
#
# image = cv2.read('image.png')
# hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
# value = 42 #whatever value you want to add
# cv2.add(hsv[:,:,2], value, hsv[:,:,2])
# image = cv2.cvtColor(hsv, cv2.COLOR_HSV2BGR)
# cv2.imwrite('out.png', image)
# print('st1')
# enhancer = ImageEnhance.Contrast(image)
# print('st2')
# factor = 1 #gives original image
# im_output = enhancer.enhance(factor)
# im_output.save('original-image.png')
#
# factor = 0.5 #decrease constrast
# im_output = enhancer.enhance(factor)
# im_output.save('less-contrast-image.png')
#
# factor = 1.2 #increase contrast
# im_output = enhancer.enhance(factor)
# im_output.save('more-contrast-image.png')
# print('okay')
# enhancer = ImageEnhance.Brightness(image)
#
# factor = 1 #gives original image
# im_output = enhancer.enhance(factor)
# im_output.save('original-image1.png')
#
# factor = 0.5 #darkens the image
# im_output = enhancer.enhance(factor)
# im_output.save('darkened-image1.png')
#
# factor = 1.2 #brightens the image
# im_output = enhancer.enhance(factor)
# im_output.save('brightened-image1.png')
#
# # creating a image object (main image)
# #im1 = Image.open(r"C:\Users\System-Pc\Desktop\flower1.jpg")
#
# # save a image using extension
# #im1 = blur10.save("blur10")
#
# #cv2.imwrite(r'C:\Users\Lenovo\Desktop\Image Preprocessing\BLUR.jpg', blur10)
# #read the image
# im = Image.open("sample-image.png")
#
# #image brightness enhancer
# enhancer = ImageEnhance.Contrast(im)
#
# factor = 1 #gives original image
# im_output = enhancer.enhance(factor)
# im_output.save('original-image.png')
#
# factor = 0.5 #decrease constrast
# im_output = enhancer.enhance(factor)
# im_output.save('less-contrast-image.png')
#
# factor = 1.5 #increase contrast
# im_output = enhancer.enhance(factor)
# im_output.save('more-contrast-image.png')
